# %% [markdown]
# # Settings

# %%
import pandas as pd
import numpy as np
import math

from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge
import xgboost as xgb

from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# # Read dataset

# %%
df = pd.read_csv('../TempForm_data_version1.csv')
df = df.drop(df.columns[0], axis=1)

# %%
df.head(10)
# Out:
#         id        time  target  weekday  month  monthday  slope  intersect  \
# 0  AS14.01  2014-03-26     6.6        3      3        26  0.070      6.220
# 1  AS14.01  2014-03-27     7.0        4      3        27  0.035      6.405
# 2  AS14.01  2014-03-28     6.4        5      3        28  0.100      6.330
# 3  AS14.01  2014-03-29     8.0        6      3        29  0.105      6.235
# 4  AS14.01  2014-03-30     7.5        0      3        30  0.230      6.260
# 5  AS14.01  2014-03-31     7.4        1      3        31  0.280      6.260
# 6  AS14.01  2014-04-01     6.0        2      4         1  0.190      6.690
# 7  AS14.01  2014-04-02     6.5        3      4         2 -0.140      7.480
# 8  AS14.01  2014-04-03     6.4        4      4         3 -0.450      8.430
# 9  AS14.01  2014-04-04     6.2        5      4         4 -0.310      7.690
#
#       social    travel    ...           screen  sms  activity    builtin  \
# 0  2198.4136  274.5110    ...     13483.521200  0.4  0.138201  1411.3234
# 1  2215.1254   91.4220    ...     13172.500000  0.4  0.131653  1016.9792
# 2  2314.2752   93.4238    ...     15432.497800  0.4  0.116179  1116.5588
# 3  2236.6556  320.0256    ...     15062.429200  0.4  0.106770  2871.8286
# 4  1686.5080  246.5516    ...     13717.483400  0.6  0.104619  3088.9634
# 5  1336.1508  246.5516    ...     10327.055200  0.4  0.094763  2965.2828
# 6   687.8700  283.2278    ...      9409.661800  0.4  0.088602  3324.0644
# 7  1508.8072  596.6892    ...      9356.013001  0.2  0.080389  3355.3024
# 8  2092.0174  370.0874    ...     12643.017401  0.2  0.081632  2065.6532
# 9  2628.2880  363.4168    ...     15258.860001  0.0  0.077839  2139.4200
#
#    communication  entertainment   finance      game   office     other
# 0      7205.7014       448.0606   38.2366    0.0000  35.0432  131.2188
# 1      7747.2740       428.6652   38.7940    0.0000   0.6020  102.7682
# 2      8141.9928       537.8682   43.0226    0.0000  37.0922   94.8460
# 3      7267.8956       720.0796   52.1752   46.6072  37.0922  125.4716
# 4      5957.9082       850.1712   45.3540   46.6072  36.4902  146.0788
# 5      4162.2590      1143.6654   36.7432   46.6072  36.4902  125.1156
# 6      3431.0358      1313.3536   34.5280   56.8424  36.4902  159.3268
# 7      3262.8386      1391.6132  135.6494  103.7906  18.4776  171.8584
# 8      4473.5032      1459.2078  167.3716   57.1834  36.5738  234.9764
# 9      6816.9812      1392.4482  182.6184   57.1834  36.5738  243.8380
#
# [10 rows x 28 columns]

# %% [markdown]
# Remove first two columns, because do not need these for prediction

# %%
df = df.drop(df.columns[0:2], axis=1)

# %%
df.head(10)
# Out:
#    target  weekday  month  monthday  slope  intersect     social    travel  \
# 0     6.6        3      3        26  0.070      6.220  2198.4136  274.5110
# 1     7.0        4      3        27  0.035      6.405  2215.1254   91.4220
# 2     6.4        5      3        28  0.100      6.330  2314.2752   93.4238
# 3     8.0        6      3        29  0.105      6.235  2236.6556  320.0256
# 4     7.5        0      3        30  0.230      6.260  1686.5080  246.5516
# 5     7.4        1      3        31  0.280      6.260  1336.1508  246.5516
# 6     6.0        2      4         1  0.190      6.690   687.8700  283.2278
# 7     6.5        3      4         2 -0.140      7.480  1508.8072  596.6892
# 8     6.4        4      4         3 -0.450      8.430  2092.0174  370.0874
# 9     6.2        5      4         4 -0.310      7.690  2628.2880  363.4168
#
#    unknown  utilities    ...           screen  sms  activity    builtin  \
# 0  47.0446   229.6172    ...     13483.521200  0.4  0.138201  1411.3234
# 1  47.0446   116.5394    ...     13172.500000  0.4  0.131653  1016.9792
# 2  47.0446   128.8210    ...     15432.497800  0.4  0.116179  1116.5588
# 3  47.0446   183.1472    ...     15062.429200  0.4  0.106770  2871.8286
# 4  47.0446   267.5282    ...     13717.483400  0.6  0.104619  3088.9634
# 5  13.2954   230.6088    ...     10327.055200  0.4  0.094763  2965.2828
# 6  19.1534   265.9968    ...      9409.661800  0.4  0.088602  3324.0644
# 7  19.1534   333.7182    ...      9356.013001  0.2  0.080389  3355.3024
# 8  19.1534   341.6490    ...     12643.017401  0.2  0.081632  2065.6532
# 9  19.1534   258.0760    ...     15258.860001  0.0  0.077839  2139.4200
#
#    communication  entertainment   finance      game   office     other
# 0      7205.7014       448.0606   38.2366    0.0000  35.0432  131.2188
# 1      7747.2740       428.6652   38.7940    0.0000   0.6020  102.7682
# 2      8141.9928       537.8682   43.0226    0.0000  37.0922   94.8460
# 3      7267.8956       720.0796   52.1752   46.6072  37.0922  125.4716
# 4      5957.9082       850.1712   45.3540   46.6072  36.4902  146.0788
# 5      4162.2590      1143.6654   36.7432   46.6072  36.4902  125.1156
# 6      3431.0358      1313.3536   34.5280   56.8424  36.4902  159.3268
# 7      3262.8386      1391.6132  135.6494  103.7906  18.4776  171.8584
# 8      4473.5032      1459.2078  167.3716   57.1834  36.5738  234.9764
# 9      6816.9812      1392.4482  182.6184   57.1834  36.5738  243.8380
#
# [10 rows x 26 columns]

# %% [markdown]
# # Make data ready for input

# %%
# split into input and output
train_X, train_y = df.iloc[:,1:], df.iloc[:,0]

# %%
trainData = xgb.DMatrix(df.iloc[:,1:], label = df.iloc[:,:0])

# %% [markdown]
# # Train model

# %%
param = {
    'max_depth': 5,
    'eta': 0.3,
    'silent': 1,
    'objective': 'reg:linear'
}
param['nthread'] = 4
num_round = 100

# %%
model = xgb.train(param, trainData, num_round)

# %%
regr = Ridge(max_iter=None, tol=0.001)

tol = [0.1, 0.01, 0.001, 0.0001]
solver = ["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"]
alpha = [0, 0.1, 1, 10, 100]
normalize = ["True", "False"]
param_grid = dict(alpha=alpha, normalize=normalize, solver=solver, tol=tol)
grid = GridSearchCV(estimator=regr, param_grid=param_grid, n_jobs=1, verbose=2)
grid_result = cross_val_score(grid, train_X, train_y, cv=3, verbose=2)
# Out:
# [CV]  ................................................................
# Fitting 3 folds for each of 84 candidates, totalling 252 fits
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=lsqr ...........................
# [CV] ............ alpha=0, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=False, solver=lsqr ...........................
# [CV] ............ alpha=0, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=False, solver=lsqr ...........................
# [CV] ............ alpha=0, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sparse_cg ......................
# [CV] ....... alpha=0, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sparse_cg ......................
# [CV] ....... alpha=0, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sparse_cg ......................
# [CV] ....... alpha=0, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sag ............................
# [CV] ............. alpha=0, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sag ............................
# [CV] ............. alpha=0, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=False, solver=sag ............................
# [CV] ............. alpha=0, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=False, solver=saga ...........................
# [CV] ............ alpha=0, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=False, solver=saga ...........................
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.3691468595811038e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.984402967158582e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.698838837058141e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.3691468595811038e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.984402967158582e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.698838837058141e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.3691468595811038e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.984402967158582e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.698838837058141e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.3691468595811038e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.984402967158582e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.698838837058141e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ............ alpha=0, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=False, solver=saga ...........................
# [CV] ............ alpha=0, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.1, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.1, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.1, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.1, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.1, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.1, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.1, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.1, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.1, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.1, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.1, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.1, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.1, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.1, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.1, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.1, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.1, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.1, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.1, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.1, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.1, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.1, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.1, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.1, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.1, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.2, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.2, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.2, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.2, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.2, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.2, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.2, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.2, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.2, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.2, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.2, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.2, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.2, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.2, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.2, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.2, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.2, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.2, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.2, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.2, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.2, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.2, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.2, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.2, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.2, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.3, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.3, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.3, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.3, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.3, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.3, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] ................................................. , total=   1.0s
# [CV]  ................................................................
# Fitting 3 folds for each of 84 candidates, totalling 252 fits
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=auto ............................
# [CV] ............. alpha=0, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=svd .............................
# [CV] .............. alpha=0, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=cholesky ........................
# [CV] ......... alpha=0, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=lsqr ............................
# [Parallel(n_jobs=1)]: Done 252 out of 252 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.33399221201984e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.917775239540206e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.690362697567043e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.33399221201984e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.917775239540206e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.690362697567043e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.33399221201984e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.917775239540206e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.690362697567043e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.33399221201984e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.917775239540206e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.690362697567043e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# [CV] ............. alpha=0, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sparse_cg .......................
# [CV] ........ alpha=0, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=sag .............................
# [CV] .............. alpha=0, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=True, solver=saga ............................
# [CV] ............. alpha=0, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=auto ...........................
# [CV] ............ alpha=0, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=svd ............................
# [CV] ............. alpha=0, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=cholesky .......................
# [CV] ........ alpha=0, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0, normalize=False, solver=lsqr ...........................
# ...
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.3, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.3, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.3, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.3, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.3, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.3, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.3, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.3, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.3, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.4, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.4, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.4, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.4, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.4, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.4, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.4, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.4, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.4, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.4, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.4, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=auto ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=svd ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=cholesky ......................
# [CV] ....... alpha=0.5, normalize=True, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=lsqr ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sparse_cg .....................
# [CV] ...... alpha=0.5, normalize=True, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=sag ...........................
# [CV] ............ alpha=0.5, normalize=True, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=True, solver=saga ..........................
# [CV] ........... alpha=0.5, normalize=True, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=auto .........................
# [CV] .......... alpha=0.5, normalize=False, solver=auto, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=svd ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=svd, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=cholesky .....................
# [CV] ...... alpha=0.5, normalize=False, solver=cholesky, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=lsqr .........................
# [CV] .......... alpha=0.5, normalize=False, solver=lsqr, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sparse_cg ....................
# [CV] ..... alpha=0.5, normalize=False, solver=sparse_cg, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=sag ..........................
# [CV] ........... alpha=0.5, normalize=False, solver=sag, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] alpha=0.5, normalize=False, solver=saga .........................
# [CV] .......... alpha=0.5, normalize=False, solver=saga, total=   0.0s
# [CV] ................................................. , total=   1.0s
# [Parallel(n_jobs=1)]: Done 252 out of 252 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.9s finished

# %%
grid_result
# Out:
# array([ 0.2203022 ,  0.25603354,  0.04076349])

# %%
regr = Ridge(max_iter=None, tol=0.001)

tol = [0.1, 0.01, 0.001, 0.0001]
solver = ["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"]
alpha = [0, 0.1, 1, 10, 100]
normalize = ["True", "False"]
param_grid = dict(alpha=alpha, normalize=normalize, solver=solver, tol=tol)
grid = GridSearchCV(estimator=regr, param_grid=param_grid, n_jobs=1, verbose=0)
results = grid.fit(train_X, train_y)
# Out:
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.0549100875303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.7316345362412704e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/mdeblaauw/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.080578761632325e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)

# %%
print("Best: %f using %s" % (results.best_score_, results.best_params_))
means = results.cv_results_['mean_test_score']
stds = results.cv_results_['std_test_score']
params = results.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.184811 using {'alpha': 0.1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'auto', 'tol': 0.1}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'auto', 'tol': 0.01}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'auto', 'tol': 0.001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'auto', 'tol': 0.0001}
# 0.118576 (0.155997) with: {'alpha': 0, 'normalize': 'True', 'solver': 'svd', 'tol': 0.1}
# 0.119227 (0.156741) with: {'alpha': 0, 'normalize': 'True', 'solver': 'svd', 'tol': 0.01}
# 0.118401 (0.155928) with: {'alpha': 0, 'normalize': 'True', 'solver': 'svd', 'tol': 0.001}
# 0.118698 (0.155829) with: {'alpha': 0, 'normalize': 'True', 'solver': 'svd', 'tol': 0.0001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.1}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.01}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.0001}
# 0.140324 (0.134366) with: {'alpha': 0, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.1}
# 0.135675 (0.140512) with: {'alpha': 0, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.01}
# 0.120198 (0.155628) with: {'alpha': 0, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.001}
# 0.121992 (0.153071) with: {'alpha': 0, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.0001}
# 0.163163 (0.134528) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.121655 (0.155607) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.121050 (0.154521) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.121465 (0.153469) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.137375 (0.133623) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sag', 'tol': 0.1}
# 0.128773 (0.145267) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sag', 'tol': 0.01}
# 0.122337 (0.152194) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sag', 'tol': 0.001}
# 0.121549 (0.153301) with: {'alpha': 0, 'normalize': 'True', 'solver': 'sag', 'tol': 0.0001}
# 0.178175 (0.136468) with: {'alpha': 0, 'normalize': 'True', 'solver': 'saga', 'tol': 0.1}
# 0.146506 (0.131290) with: {'alpha': 0, 'normalize': 'True', 'solver': 'saga', 'tol': 0.01}
# 0.124171 (0.151126) with: {'alpha': 0, 'normalize': 'True', 'solver': 'saga', 'tol': 0.001}
# 0.121753 (0.153200) with: {'alpha': 0, 'normalize': 'True', 'solver': 'saga', 'tol': 0.0001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'auto', 'tol': 0.1}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'auto', 'tol': 0.01}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'auto', 'tol': 0.001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'auto', 'tol': 0.0001}
# 0.119402 (0.156808) with: {'alpha': 0, 'normalize': 'False', 'solver': 'svd', 'tol': 0.1}
# 0.118401 (0.155928) with: {'alpha': 0, 'normalize': 'False', 'solver': 'svd', 'tol': 0.01}
# 0.118523 (0.155760) with: {'alpha': 0, 'normalize': 'False', 'solver': 'svd', 'tol': 0.001}
# 0.119524 (0.156640) with: {'alpha': 0, 'normalize': 'False', 'solver': 'svd', 'tol': 0.0001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.1}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.01}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.001}
# 0.121486 (0.153427) with: {'alpha': 0, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.0001}
# 0.140324 (0.134366) with: {'alpha': 0, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.1}
# 0.135675 (0.140512) with: {'alpha': 0, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.01}
# 0.120198 (0.155628) with: {'alpha': 0, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.001}
# 0.121992 (0.153071) with: {'alpha': 0, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.0001}
# 0.163163 (0.134528) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.121655 (0.155607) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.121050 (0.154521) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.121465 (0.153469) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.093850 (0.158984) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sag', 'tol': 0.1}
# 0.130260 (0.142929) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sag', 'tol': 0.01}
# 0.122366 (0.152391) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sag', 'tol': 0.001}
# 0.121541 (0.153300) with: {'alpha': 0, 'normalize': 'False', 'solver': 'sag', 'tol': 0.0001}
# 0.166992 (0.143938) with: {'alpha': 0, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# 0.143379 (0.134485) with: {'alpha': 0, 'normalize': 'False', 'solver': 'saga', 'tol': 0.01}
# 0.123989 (0.151173) with: {'alpha': 0, 'normalize': 'False', 'solver': 'saga', 'tol': 0.001}
# 0.121741 (0.153187) with: {'alpha': 0, 'normalize': 'False', 'solver': 'saga', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.0001}
# 0.142465 (0.123147) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.1}
# 0.162362 (0.142159) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.01}
# 0.176765 (0.120812) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.001}
# 0.177286 (0.119858) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.0001}
# 0.178300 (0.115516) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.183731 (0.110115) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.177269 (0.119903) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.177336 (0.119787) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.152215 (0.156126) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.1}
# 0.179198 (0.118670) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.01}
# 0.177467 (0.119725) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.001}
# 0.177455 (0.119605) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.0001}
# 0.167999 (0.125528) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.1}
# 0.179801 (0.118406) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.01}
# 0.177932 (0.119149) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.001}
# 0.177413 (0.119660) with: {'alpha': 0.1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.0001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.1}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.01}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.001}
# 0.177367 (0.119729) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.0001}
# 0.142465 (0.123147) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.1}
# 0.162362 (0.142159) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.01}
# 0.176765 (0.120812) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.001}
# 0.177286 (0.119858) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.0001}
# 0.178300 (0.115516) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.183731 (0.110115) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.177269 (0.119903) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.177336 (0.119787) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.163827 (0.150804) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.1}
# 0.180267 (0.115690) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.01}
# 0.177364 (0.119648) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.001}
# 0.177367 (0.119722) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.0001}
# 0.184811 (0.112381) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# 0.178498 (0.119919) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.01}
# 0.177967 (0.119169) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.001}
# 0.177427 (0.119672) with: {'alpha': 0.1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'auto', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'svd', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.0001}
# 0.121278 (0.073824) with: {'alpha': 1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.1}
# 0.132008 (0.069000) with: {'alpha': 1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.01}
# 0.133550 (0.069108) with: {'alpha': 1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.001}
# 0.133869 (0.068745) with: {'alpha': 1, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.0001}
# 0.122317 (0.074581) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.133617 (0.068680) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.133884 (0.068754) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.133902 (0.068708) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.128645 (0.078227) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.1}
# 0.133872 (0.068592) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.01}
# 0.133921 (0.068753) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.001}
# 0.133867 (0.068764) with: {'alpha': 1, 'normalize': 'True', 'solver': 'sag', 'tol': 0.0001}
# 0.134699 (0.072756) with: {'alpha': 1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.1}
# 0.134000 (0.068830) with: {'alpha': 1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.01}
# 0.133879 (0.068754) with: {'alpha': 1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.001}
# 0.133883 (0.068737) with: {'alpha': 1, 'normalize': 'True', 'solver': 'saga', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'auto', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'svd', 'tol': 0.0001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.1}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.01}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.001}
# 0.133886 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.0001}
# 0.121278 (0.073824) with: {'alpha': 1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.1}
# 0.132008 (0.069000) with: {'alpha': 1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.01}
# 0.133550 (0.069108) with: {'alpha': 1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.001}
# 0.133869 (0.068745) with: {'alpha': 1, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.0001}
# 0.122317 (0.074581) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.1}
# 0.133617 (0.068680) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.01}
# 0.133884 (0.068754) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.001}
# 0.133902 (0.068708) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.0001}
# 0.130383 (0.065284) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.1}
# 0.134285 (0.069149) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.01}
# 0.133840 (0.068782) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.001}
# 0.133885 (0.068732) with: {'alpha': 1, 'normalize': 'False', 'solver': 'sag', 'tol': 0.0001}
# 0.138316 (0.075193) with: {'alpha': 1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# 0.133957 (0.068626) with: {'alpha': 1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.01}
# 0.133896 (0.068733) with: {'alpha': 1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.001}
# 0.133890 (0.068731) with: {'alpha': 1, 'normalize': 'False', 'solver': 'saga', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'auto', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'auto', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'auto', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'auto', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'svd', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'svd', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'svd', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'svd', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.0001}
# -0.007275 (0.055027) with: {'alpha': 10, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.1}
# -0.006539 (0.057330) with: {'alpha': 10, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.01}
# -0.006563 (0.057327) with: {'alpha': 10, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.001}
# -0.006379 (0.057201) with: {'alpha': 10, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.0001}
# -0.006162 (0.055170) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.1}
# -0.006539 (0.057330) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.01}
# -0.006379 (0.057201) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.0001}
# -0.005981 (0.055793) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sag', 'tol': 0.1}
# -0.005922 (0.056950) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sag', 'tol': 0.01}
# -0.006385 (0.057202) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sag', 'tol': 0.001}
# -0.006378 (0.057197) with: {'alpha': 10, 'normalize': 'True', 'solver': 'sag', 'tol': 0.0001}
# -0.007818 (0.059198) with: {'alpha': 10, 'normalize': 'True', 'solver': 'saga', 'tol': 0.1}
# -0.006319 (0.057210) with: {'alpha': 10, 'normalize': 'True', 'solver': 'saga', 'tol': 0.01}
# -0.006383 (0.057214) with: {'alpha': 10, 'normalize': 'True', 'solver': 'saga', 'tol': 0.001}
# -0.006378 (0.057198) with: {'alpha': 10, 'normalize': 'True', 'solver': 'saga', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'auto', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'auto', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'auto', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'auto', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'svd', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'svd', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'svd', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'svd', 'tol': 0.0001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.1}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.01}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.0001}
# -0.007275 (0.055027) with: {'alpha': 10, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.1}
# -0.006539 (0.057330) with: {'alpha': 10, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.01}
# -0.006563 (0.057327) with: {'alpha': 10, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.001}
# -0.006379 (0.057201) with: {'alpha': 10, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.0001}
# -0.006162 (0.055170) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.1}
# -0.006539 (0.057330) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.01}
# -0.006379 (0.057201) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.0001}
# -0.005445 (0.057102) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sag', 'tol': 0.1}
# -0.006218 (0.057293) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sag', 'tol': 0.01}
# -0.006418 (0.057250) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sag', 'tol': 0.001}
# -0.006377 (0.057198) with: {'alpha': 10, 'normalize': 'False', 'solver': 'sag', 'tol': 0.0001}
# -0.006009 (0.056834) with: {'alpha': 10, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# -0.006171 (0.056825) with: {'alpha': 10, 'normalize': 'False', 'solver': 'saga', 'tol': 0.01}
# -0.006371 (0.057212) with: {'alpha': 10, 'normalize': 'False', 'solver': 'saga', 'tol': 0.001}
# -0.006377 (0.057199) with: {'alpha': 10, 'normalize': 'False', 'solver': 'saga', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'auto', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'auto', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'auto', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'auto', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'svd', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'svd', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'svd', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'svd', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'cholesky', 'tol': 0.0001}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.1}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.01}
# -0.075867 (0.067441) with: {'alpha': 100, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.001}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'lsqr', 'tol': 0.0001}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.1}
# -0.075867 (0.067441) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.01}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.001}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sparse_cg', 'tol': 0.0001}
# -0.075816 (0.067636) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sag', 'tol': 0.1}
# -0.075874 (0.067481) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sag', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sag', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'True', 'solver': 'sag', 'tol': 0.0001}
# -0.075824 (0.067460) with: {'alpha': 100, 'normalize': 'True', 'solver': 'saga', 'tol': 0.1}
# -0.075853 (0.067478) with: {'alpha': 100, 'normalize': 'True', 'solver': 'saga', 'tol': 0.01}
# -0.075886 (0.067472) with: {'alpha': 100, 'normalize': 'True', 'solver': 'saga', 'tol': 0.001}
# -0.075885 (0.067472) with: {'alpha': 100, 'normalize': 'True', 'solver': 'saga', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'auto', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'auto', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'auto', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'auto', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'svd', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'svd', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'svd', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'svd', 'tol': 0.0001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.1}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.01}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.001}
# -0.075885 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'cholesky', 'tol': 0.0001}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.1}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.01}
# -0.075867 (0.067441) with: {'alpha': 100, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.001}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'lsqr', 'tol': 0.0001}
# -0.075880 (0.067438) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.1}
# -0.075867 (0.067441) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.01}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.001}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sparse_cg', 'tol': 0.0001}
# -0.075568 (0.067314) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sag', 'tol': 0.1}
# -0.075897 (0.067475) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sag', 'tol': 0.01}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sag', 'tol': 0.001}
# -0.075886 (0.067473) with: {'alpha': 100, 'normalize': 'False', 'solver': 'sag', 'tol': 0.0001}
# -0.076040 (0.067501) with: {'alpha': 100, 'normalize': 'False', 'solver': 'saga', 'tol': 0.1}
# -0.075872 (0.067453) with: {'alpha': 100, 'normalize': 'False', 'solver': 'saga', 'tol': 0.01}
# -0.075886 (0.067472) with: {'alpha': 100, 'normalize': 'False', 'solver': 'saga', 'tol': 0.001}
# -0.075880 (0.067479) with: {'alpha': 100, 'normalize': 'False', 'solver': 'saga', 'tol': 0.0001}
